# %% [markdown]
# <a href="https://colab.research.google.com/github/dzeyfrancisbuhayan-ui/cs1-python-Emerald-Buhayan/blob/main/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_total(price, quantity):
    return price * quantity

price = float(input("Enter the price of one item: "))
quantity = int(input("Enter the number of items purchased: "))

total = calculate_total(price, quantity)

print("Total price:", total)
# Out:
# Enter the price of one item: 10
# Enter the number of items purchased: 2
# Total price: 20.0
